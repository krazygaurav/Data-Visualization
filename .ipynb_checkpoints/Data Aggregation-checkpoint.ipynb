# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_big = pd.read_csv("obama_too_big.csv", parse_dates=['year_month'])
data = pd.read_csv("obama.csv", parse_dates=['year_month'])

# %%
data.head()
# Out:
#   year_month  survey_organization  approve_percent  disapprove_percent
# 0 2009-01-01             ABC/Post             80.0                15.0
# 1 2009-01-01               AP-GFK             74.0                15.0
# 2 2009-01-01                  CNN             84.0                14.0
# 3 2009-01-01  Democracy Corps (D)             51.0                20.0
# 4 2009-01-01       Diageo/Hotline             64.0                 6.5

# %%
data_big.head()
# Out:
#   year_month survey_organization  approve_percent  disapprove_percent
# 0 2009-01-01      Generated Data             67.0                31.0
# 1 2009-01-01      Harris (Phone)             60.0                29.0
# 2 2009-01-01      Generated Data             65.9                19.1
# 3 2009-01-01      Generated Data             64.6                18.4
# 4 2009-01-01      Generated Data             83.3                11.7

# %%
data_big.describe(include="all")
# Out:
#                  year_month survey_organization  approve_percent  \
# count                 65499               65499     65499.000000
# unique                   85                 100              NaN
# top     2009-07-01 00:00:00      Generated Data              NaN
# freq                   1150               64190              NaN
# first   2009-01-01 00:00:00                 NaN              NaN
# last    2016-01-01 00:00:00                 NaN              NaN
# mean                    NaN                 NaN        46.285383
# std                     NaN                 NaN         8.053855
# min                     NaN                 NaN        15.700000
# 25%                     NaN                 NaN        41.000000
# 50%                     NaN                 NaN        45.900000
# 75%                     NaN                 NaN        50.900000
# max                     NaN                 NaN        98.600000
#
#         disapprove_percent
# count         65499.000000
# unique                 NaN
# top                    NaN
# freq                   NaN
# first                  NaN
# last                   NaN
# mean             47.774290
# std               8.795269
# min              -7.300000
# 25%              43.300000
# 50%              48.600000
# 75%              53.400000
# max              83.100000

# %%
data.describe(include="all")
# Out:
#                  year_month survey_organization  approve_percent  \
# count                  1530                1530      1530.000000
# unique                   97                 110              NaN
# top     2009-07-01 00:00:00           Rasmussen              NaN
# freq                     23                  97              NaN
# first   2009-01-01 00:00:00                 NaN              NaN
# last    2017-01-01 00:00:00                 NaN              NaN
# mean                    NaN                 NaN        46.725163
# std                     NaN                 NaN         6.210641
# min                     NaN                 NaN        26.500000
# 25%                     NaN                 NaN        43.000000
# 50%                     NaN                 NaN        46.000000
# 75%                     NaN                 NaN        50.000000
# max                     NaN                 NaN        84.000000
#
#         disapprove_percent
# count          1530.000000
# unique                 NaN
# top                    NaN
# freq                   NaN
# first                  NaN
# last                   NaN
# mean             47.540850
# std               6.914606
# min               6.500000
# 25%              45.000000
# 50%              48.500000
# 75%              52.000000
# max              71.500000

# %%
data_big.shape
# Out:
# (65499, 4)

# %%
plt.plot(data_big.year_month, data_big.approve_percent, 'o', markersize=2, alpha=0.3)
plt.show()

# %%
#Data is too much in data_big. So I am sampling only 10% of the data
sampled = data_big.sample(frac=0.1)

# %%
plt.plot(sampled.year_month, sampled.approve_percent, 'o', markersize=2, alpha=0.3)
plt.xlabel("Year")
plt.ylabel("Acceptance Level (%)")
plt.show()
